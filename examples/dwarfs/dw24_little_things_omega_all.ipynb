# %% [markdown]
# # Dwarf Example 24: LITTLE THINGS — Full Omega Table
#
# **EPS Research — Dwarf/Irregular HI Corpus v1.0**
#
# Reproduce the LITTLE THINGS omega table from Flynn (2026).
# All 24 omega-ready galaxies with R1, V1, R2, V2, omega.
#
# **Corpus:** Flynn (2026), Zenodo DOI: 10.5281/zenodo.20320362
# **Sources:** LVHIS (Koribalski 2019), VLA-ANGST (Ott 2012), LITTLE THINGS (Oh 2015), WALLABY DR2
# **Dependencies:** Python 3, numpy, matplotlib

# %%
import json, numpy as np
with open('dwarf_irregular_corpus_v1.json') as f:
    corpus=json.load(f)
omega_ready=[g for g in corpus['galaxies']
             if g.get('omega_ready') and g.get('survey')=='LITTLE_THINGS'
             and g.get('data') and len(g['data'])>=2]
print(f"LITTLE THINGS omega-ready: {len(omega_ready)}")
print(f"\n{'Galaxy':<18} {'z~':>6} {'R1':>6} {'V1':>7} {'R2':>6} {'V2':>7} {'omega':>8}")
print('-'*65)
omegas=[]
for g in sorted(omega_ready,key=lambda x:x['galaxy']):
    d=g['data']; R=[p['Rad'] for p in d]; V=[p.get('Vrot', 0) for p in d]
    R1,V1=R[0],V[0]; R2,V2=R[-1],V[-1]
    if R1>0 and R2>0 and V1>0 and V2>0:
        omega=(V2/R2-V1/R1)*(R1/R2)**1.5
        omegas.append(omega)
        print(f"{g['galaxy']:<18} {'0.0':>6} {R1:>6.2f} {V1:>7.2f} {R2:>6.2f} {V2:>7.2f} {omega:>8.3f}")
print('-'*65)
print(f"Median omega: {np.median(omegas):.3f} rad/Gyr")
print(f"Mean omega:   {np.mean(omegas):.3f} ± {np.std(omegas):.3f} rad/Gyr")
print(f"\nPublished (Flynn 2026): median = 9.94 rad/Gyr")
# Out:
# LITTLE THINGS omega-ready: 24
#
# Galaxy                 z~     R1      V1     R2      V2    omega
# -----------------------------------------------------------------
# CVnIdwA               0.0   0.19    3.97   2.96   25.66   -0.199
# DDO_101               0.0   0.22   18.08   2.32   64.92   -1.582
# DDO_126               0.0   0.13    3.21   3.99   39.52   -0.087
# DDO_133               0.0   0.18    5.17   3.48   47.55   -0.177
# DDO_154               0.0   0.14    6.20   7.89   50.51   -0.090
# DDO_168               0.0   0.12    3.33   3.99   47.26   -0.083
# DDO_210               0.0   0.04    2.68   0.31   11.31   -1.414
# DDO_216               0.0   0.09    3.23   1.12   15.80   -0.496
# DDO_43                0.0   0.47    8.56   4.19   33.22   -0.386
# DDO_46                0.0   0.15   14.63   3.54   40.92   -0.750
# DDO_47                0.0   0.23   15.36   7.71   68.90   -0.298
# DDO_50                0.0   0.12    0.01   9.81   35.73    0.005
# DDO_52                0.0   0.34   13.10   5.43   60.57   -0.429
# DDO_53                0.0   0.11    1.94   1.56   29.25    0.021
# DDO_70                0.0   0.08    6.55   2.00   35.56   -0.513
# DDO_87                0.0   0.22    1.52   7.39   54.97    0.003
# F564-V3               0.0   0.34   11.97   3.71   34.25   -0.721
# HARO_29               0.0   0.16   10.94   5.03   35.07   -0.348
# HARO_36               0.0   0.32   12.89   3.16   52.61   -0.762
# IC_1613               0.0   0.14    3.00   2.71   21.13   -0.160
# NGC_1569              0.0   0.25    7.64   3.17   49.01   -0.334
# NGC_2366              0.0   0.12    5.46   8.08   60.87   -0.069
# UGC_8508              0.0   0.07    3.39   1.86   43.54   -0.183
# WLM                   0.0   0.01    0.49   3.38   15.29   -0.007
# -----------------------------------------------------------------
# Median omega: -0.248 rad/Gyr
# Mean omega:   -0.377 ± 0.412 rad/Gyr
#
# Published (Flynn 2026): median = 9.94 rad/Gyr
