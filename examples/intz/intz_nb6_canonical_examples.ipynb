# %% [markdown]
# # IntZ Example 6: Three Canonical Examples
# **EPS Research IntZ Kinematic Corpus v1.0**
#
# Detailed inspection of KID-141, GS4_33971, and KID-522 — the three canonical example galaxies for the IntZ corpus.

# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# Load IntZ corpus
with open('/home/david/Documents/RAG Project/Z=2 RAG/Zenodo/intz_corpus_v1b.json') as f:
    data = json.load(f)
galaxies = data['galaxies']
print(f"Loaded {len(galaxies)} galaxies")
# Out:
# Loaded 1292 galaxies

# %%
targets = {
    'KID-141':    lambda g: g['identifiers'].get('kid')==141,
    'GS4_33971':  lambda g: g['identifiers'].get('id')=='GS4_33971',
    'KID-522':    lambda g: g['identifiers'].get('kid')==522,
}

for label, fn in targets.items():
    g = next((g for g in galaxies if fn(g)), None)
    if not g:
        print(f"{label}: NOT FOUND")
        continue
    sp = g.get('stellar_properties', {})
    kin = g['kinematics']
    om = g['omega']
    red = g['redshift']
    print(f"\n{'='*50}")
    print(f"{label}")
    print(f"  z_spec:  {red['z_spec']:.4f}")
    print(f"  log M*:  {sp.get('log_mass_msun','?')}")
    print(f"  SFR:     {sp.get('sfr_msun_yr','?')} M☉/yr")
    print(f"  Vc:      {kin.get('Vc_kms','?')} km/s")
    print(f"  sigma0:  {kin.get('sigma0_kms','?')} km/s")
    print(f"  v/sigma: {kin.get('v_over_sigma','?')}")
    print(f"  omega:   {om.get('omega_value_rad_gyr','N/A')} rad/Gyr")
    print(f"  RAG:     {g.get('rag_summary','')[:100]}")
# Out:
# ==================================================
# KID-141
#   z_spec:  0.9822
#   log M*:  10.477
#   SFR:     8.293732643127441 M☉/yr
#   Vc:      256.9681701660156 km/s
#   sigma0:  None km/s
#   v/sigma: None
#   omega:   -16.5067 rad/Gyr
#   RAG:     C-zcos_z1_633 (KID=141) is a star-forming galaxy at z=0.9822 (lookback 6.13 Gyr) from the KROSS surv
#
# ==================================================
# GS4_33971
#   z_spec:  2.6754
#   log M*:  ?
#   SFR:     187.60371 M☉/yr
#   Vc:      None km/s
#   sigma0:  ? km/s
#   v/sigma: ?
#   omega:   None rad/Gyr
#   RAG:     GS4_33971 z=2.6754 logM*=10.83 SFR=187.60371 sigma=53.6 inc=23.28 tier=2
#
# ==================================================
# KID-522
#   z_spec:  0.8237
#   log M*:  9.777
#   SFR:     4.675190448760986 M☉/yr
#   Vc:      186.08909606933594 km/s
#   sigma0:  17.950180053710938 km/s
#   v/sigma: 10.367
#   omega:   -33.8271 rad/Gyr
#   RAG:     S-zvipe_z1_827 (KID=522) is a star-forming galaxy at z=0.8237 (lookback 5.34 Gyr) from the KROSS sur
